# %% [markdown]
# # Introduction

# %% [markdown]
# The idea is to use LiftRsNumber.py to convert old rs number to new rs number, and use the data file b132_SNPChrPosOnRef_37_1.bcp.gz (a data file containing each dbSNP and its positions in NCBI build 37).
# 1. Extract and lift rs numbers
# Use the tools LiftRsNumber.py to lift the rs number in the map file from old build to new build.
# 2. Lookup SNP positions from rs number
# dbSNP provides a file b132_SNPChrPosOnRef_37_1.bcp.gz which contains rsNumber, chromosome and its position. Use this file along with the new rsNumber obtained in the first step. In practice, some rs numbers do not exist in build 132, or not suitable to be considered ( e.g. they do not reside on human reference, or they are mapped to multiple locations, these scenarios are noted by the chromosome column with values like "AltOnly", "Multi", "NotOn", "PAR", "Un"), we can drop them in the liftover procedure. We will obtain the rs number and its position in the new build after this step.

# %%
import os
import io
import sys
import re
import json
import gzip
import shlex, subprocess
import pandas as pd
import numpy as np
# from joblib import Parallel, delayed

# %% [markdown]
# # Extract and lift rs numbers

# %% [markdown]
# ## Load SNP History and Archive files

# %%
# %%time
RS_HISTORY = set()  # store rs

# record obsolete rs number
with gzip.open('/home/tun01458/lib/dbSNP/SNPHistory.bcp.gz', 'rb') as f_gz:
    f_history = io.BufferedReader(f_gz)  # speed up read
    for line in f_gz:
        line = line.decode('utf8')  # covert byte to string
        # print(line)
        fd = line.strip().split('\t')
        if line.find('re-activ') < 0:
            RS_HISTORY.add(fd[0])
# Out:
# CPU times: user 1min 13s, sys: 1.82 s, total: 1min 15s
# Wall time: 1min 15s

# %%
# %%time
RS_MERGE = dict()  # high_rs -> (lower_rs, current_rs)

# record rs number merge history
with gzip.open('/home/tun01458/lib/dbSNP/RsMergeArch.bcp.gz', 'rb') as f_gz:
    f_archive = io.BufferedReader(f_gz)  # speed up read
    for line in f_archive:
        line = line.decode('utf8')  # covert byte to string
        fd = line.strip().split('\t')
        h, l = fd[0], fd[1]
        c = fd[6]
        RS_MERGE[h] = (l, c)
# Out:
# CPU times: user 44.5 s, sys: 4.83 s, total: 49.4 s
# Wall time: 49.4 s

# %% [markdown]
# ## Collect rsNumbers

# %%
# all files
build36_genotype_filenames = os.listdir('user_data/build36_genotype/')
print(len(build36_genotype_filenames))
build36_genotype_filenames
# Out:
# 66
# ['user123_file54_yearofbirth_unknown_sex_unknown.23andme.txt',
#  'user549_file252_yearofbirth_1948_sex_XY.23andme.txt',
#  'user202_file85_yearofbirth_unknown_sex_unknown.23andme.txt',
#  'user146_file62_yearofbirth_1971_sex_XY.23andme.txt',
#  'user64_file30_yearofbirth_1965_sex_XY.23andme.txt',
#  'user595_file277_yearofbirth_unknown_sex_unknown.23andme.txt',
#  'user26_file10_yearofbirth_unknown_sex_unknown.23andme.txt',
#  'user22_file8_yearofbirth_1975_sex_XY.23andme.txt',
#  'user14_file6_yearofbirth_unknown_sex_unknown.23andme.txt',
#  'user481_file215_yearofbirth_unknown_sex_unknown.23andme.txt',
#  'user468_file200_yearofbirth_1978_sex_XX.23andme.txt',
#  'user347_file157_yearofbirth_1952_sex_XX.23andme.txt',
#  'user296_file127_yearofbirth_unknown_sex_unknown.23andme.txt',
#  'user865_file427_yearofbirth_1979_sex_XY.23andme.txt',
#  'user75_file39_yearofbirth_1982_sex_XY.23andme.txt',
#  'user60_file27_yearofbirth_1982_sex_XY.23andme.txt',
#  'user55_file24_yearofbirth_unknown_sex_unknown.23andme.txt',
#  'user279_file113_yearofbirth_unknown_sex_unknown.23andme.txt',
#  'user139_file59_yearofbirth_unknown_sex_unknown.23andme.txt',
#  'user430_file328_yearofbirth_1986_sex_XX.23andme.txt',
#  'user99_file49_yearofbirth_1986_sex_XY.23andme.txt',
#  'user325_file149_yearofbirth_1987_sex_XY.23andme.txt',
#  'user285_file118_yearofbirth_1976_sex_XY.23andme.txt',
#  'user42_file18_yearofbirth_1985_sex_XY.23andme.txt',
#  'user11_file176_yearofbirth_unknown_sex_unknown.23andme.txt',
#  'user13_file4_yearofbirth_1979_sex_XY.23andme.txt',
#  'user159_file67_yearofbirth_1984_sex_XX.23andme.txt',
#  'user294_file125_yearofbirth_1963_sex_XY.23andme.txt',
#  'user10_file3_yearofbirth_1982_sex_XY.23andme.txt',
#  'user74_file48_yearofbirth_unknown_sex_XY.23andme.txt',
#  'user341_file155_yearofbirth_unknown_sex_unknown.23andme.txt',
#  'user262_file103_yearofbirth_1975_sex_XY.23andme.txt',
#  'user33_file12_yearofbirth_unknown_sex_unknown.23andme.txt',
#  'user36_file14_yearofbirth_1986_sex_XY.23andme.txt',
#  'user368_file168_yearofbirth_1958_sex_XX.23andme.txt',
#  'user397_file178_yearofbirth_1961_sex_XY.23andme.txt',
#  'user207_file89_yearofbirth_unknown_sex_unknown.23andme.txt',
#  'user276_file110_yearofbirth_1972_sex_XY.23andme.txt',
#  'user441_file199_yearofbirth_1989_sex_XY.23andme.txt',
#  'user1_file9_yearofbirth_1985_sex_XY.23andme.txt',
#  'user495_file223_yearofbirth_1965_sex_XX.23andme.txt',
#  'user411_file183_yearofbirth_unknown_sex_unknown.23andme.txt',
#  'user86_file159_yearofbirth_1986_sex_XY.23andme.txt',
#  'user539_file246_yearofbirth_1983_sex_XX.23andme.txt',
#  'user463_file197_yearofbirth_1985_sex_XY.23andme.txt',
#  'user125_file56_yearofbirth_1976_sex_XY.23andme.txt',
#  'user80_file41_yearofbirth_1979_sex_XY.23andme.txt',
#  'user81_file42_yearofbirth_1977_sex_XY.23andme.txt',
#  'user8_file2_yearofbirth_unknown_sex_XX.23andme.txt',
#  'user437_file190_yearofbirth_1973_sex_XY.23andme.txt',
#  'user161_file68_yearofbirth_unknown_sex_unknown.23andme.txt',
#  'user366_file167_yearofbirth_1950_sex_XY.23andme.txt',
#  'user6882_file6340_yearofbirth_1982_sex_XX.23andme.txt',
#  'user337_file152_yearofbirth_unknown_sex_unknown.23andme.txt',
#  'user330_file146_yearofbirth_unknown_sex_XY.23andme.txt',
#  'user160_file153_yearofbirth_1954_sex_unknown.23andme.txt',
#  'user17_file143_yearofbirth_unknown_sex_XX.23andme.txt',
#  'user363_file165_yearofbirth_unknown_sex_unknown.23andme.txt',
#  'user35_file5822_yearofbirth_unknown_sex_XY.23andme.txt',
#  'user380_file172_yearofbirth_unknown_sex_XY.23andme.txt',
#  'user502_file226_yearofbirth_unknown_sex_unknown.23andme.txt',
#  'user287_file120_yearofbirth_unknown_sex_unknown.23andme.txt',
#  'user323_file142_yearofbirth_1983_sex_XY.23andme.txt',
#  'user429_file187_yearofbirth_1950_sex_XY.23andme.txt',
#  'user63_file31_yearofbirth_unknown_sex_unknown.23andme.txt',
#  'user62_file29_yearofbirth_1966_sex_XY.23andme.txt']

# %%
# union all rsID, not include SNP starting with 'i'
buid36_rs_union = set()
for i, filename in enumerate(build36_genotype_filenames):
    print('{}/{}'.format(i + 1, len(build36_genotype_filenames)), end='\r')
    build36_genotype = pd.read_csv(os.path.join('user_data/build36_genotype/',
                                                filename),
                                   sep='\t',
                                   header=None,
                                   usecols=[0],
                                   names=['rsid'],
                                   comment='#')

    # union
    buid36_rs_union = buid36_rs_union | set(
        [x[2:] for x in build36_genotype['rsid'] if x[0:2] == 'rs'])

print()
print(len(buid36_rs_union))
# Out:
# 66/66
# 1266046

# %% [markdown]
# ## Lift over rsNumber

# %%
RsNum_MAP = {}
for rsNum in buid36_rs_union:
    # print(rsNum)
    # rs number not appear in RS_MERGE -> there is no merge on this rs
    if rsNum not in RS_MERGE:
        # print(rsNum, rsNum, "unchanged")
        continue
    # lift rs number
    while True:
        if rsNum in RS_MERGE:
            rsLow, rsCurrent = RS_MERGE[rsNum]
            if rsCurrent not in RS_HISTORY:
                RsNum_MAP['rs' + str(rsNum)] = 'rs' + str(rsCurrent)
                # print(rsNum, rsCurrent, "lifted")
                break
            else:
                rsNum = rsLow
        else:
            # print(rsNum, rsNum, "unlifted" )
            break
            
print(len(RsNum_MAP))
RsNum_MAP
# Out:
# 1134
# {'rs28935178': 'rs132630275',
#  'rs386420751': 'rs112184173',
#  'rs11617079': 'rs12015',
#  'rs4141926': 'rs3126628',
#  'rs35774380': 'rs2750557',
#  'rs10499304': 'rs9480047',
#  'rs11069912': 'rs9515509',
#  'rs28634043': 'rs9701850',
#  'rs28934899': 'rs79931499',
#  'rs28929500': 'rs137854479',
#  'rs10851319': 'rs9523445',
#  'rs750650420': 'rs606231234',
#  'rs61726457': 'rs137852632',
#  'rs6507641': 'rs16809',
#  'rs12560648': 'rs9550658',
#  'rs17382334': 'rs11540037',
#  'rs66616071': 'rs66616070',
#  'rs28937303': 'rs137852466',
#  'rs28546178': 'rs5888257',
#  'rs12818259': 'rs1966010',
#  'rs4073952': 'rs4052427',
#  'rs28929487': 'rs121917873',
#  'rs17152154': 'rs2229862',
#  'rs28930972': 'rs121908728',
#  'rs10454556': 'rs9524587',
#  'rs28935212': 'rs137852392',
#  'rs35861491': 'rs34049890',
#  'rs28358271': 'rs7520428',
#  'rs12461010': 'rs679057',
#  'rs28937288': 'rs137852441',
#  'rs35964018': 'rs2522626',
#  'rs4987310': 'rs2229569',
#  'rs28491442': 'rs9783095',
#  'rs200931747': 'rs193303033',
#  'rs34787276': 'rs2755727',
#  'rs13383900': 'rs11542286',
#  'rs12017848': 'rs9591555',
#  'rs62638190': 'rs104894373',
#  'rs28670911': 'rs4631',
#  'rs9984077': 'rs8788',
#  'rs3748041': 'rs1698063',
#  'rs2722270': 'rs1124268',
#  'rs35679774': 'rs3853058',
#  'rs35188937': 'rs2751750',
#  'rs769738334': 'rs587699560',
#  'rs730880332': 'rs200989046',
#  'rs34755388': 'rs2540363',
#  'rs28935202': 'rs111033613',
#  'rs751357509': 'rs587779817',
#  'rs28358871': 'rs9326623',
#  'rs28929491': 'rs121912974',
#  'rs36082732': 'rs2524838',
#  'rs33963603': 'rs5785194',
#  'rs28932775': 'rs121913669',
#  'rs11535853': 'rs2076740',
#  'rs2239330': 'rs2230671',
#  'rs4297265': 'rs2228420',
#  'rs556894766': 'rs2303973',
#  'rs12178316': 'rs9480021',
#  'rs12560757': 'rs9561474',
#  'rs28939690': 'rs121909058',
#  'rs7179270': 'rs2229515',
#  'rs4668123': 'rs2228171',
#  'rs3205229': 'rs2229002',
#  'rs12183900': 'rs9464432',
#  'rs10479002': 'rs12777',
#  'rs386564135': 'rs2230336',
#  'rs12912744': 'rs3917221',
#  'rs17537869': 'rs1143687',
#  'rs28937286': 'rs111033614',
#  'rs12017462': 'rs9587165',
#  'rs28357978': 'rs9701779',
#  'rs2853509': 'rs527236208',
#  'rs28937279': 'rs137852418',
#  'rs12718341': 'rs2230349',
#  'rs7243988': 'rs2269219',
#  'rs28937268': 'rs137852404',
#  'rs12183365': 'rs9466504',
#  'rs11069557': 'rs9519369',
#  'rs760354546': 'rs202193006',
#  'rs28934278': 'rs137852865',
#  'rs545540376': 'rs2908201',
#  'rs12183646': 'rs9462845',
#  'rs3731062': 'rs2229089',
#  'rs71650840': 'rs11163752',
#  'rs10747165': 'rs9507091',
#  'rs10080265': 'rs9474718',
#  'rs751779946': 'rs587777139',
#  'rs35373755': 'rs2759843',
#  'rs11487802': 'rs7544325',
#  'rs28549246': 'rs9524685',
#  'rs4442356': 'rs3964040',
#  'rs35955256': 'rs2525184',
#  'rs4713433': 'rs74992754',
#  'rs4580491': 'rs2332471',
#  'rs34025717': 'rs2571894',
#  'rs8077302': 'rs2072279',
#  'rs5743293': 'rs2066847',
#  'rs4292042': 'rs2356639',
#  'rs28937292': 'rs137852444',
#  'rs28940584': 'rs104893980',
#  'rs560387829': 'rs12533596',
#  'rs80359889': 'rs80338933',
#  'rs4364877': 'rs2892746',
#  'rs4238325': 'rs2899612',
#  'rs4458268': 'rs2228384',
#  'rs12183837': 'rs9445958',
#  'rs72663315': 'rs12521276',
#  'rs12182055': 'rs9465192',
#  'rs571209950': 'rs10508533',
#  'rs12180499': 'rs9486813',
#  'rs6586179': 'rs1051339',
#  'rs140311549': 'rs11554923',
#  'rs1793987': 'rs1793986',
#  'rs9724556': 'rs4047357',
#  'rs10871231': 'rs9553760',
#  'rs12763104': 'rs9423029',
#  'rs36014018': 'rs2524466',
#  'rs28942069': 'rs104894108',
#  'rs28392537': 'rs8179287',
#  'rs7109362': 'rs499363',
#  'rs35104847': 'rs5989620',
#  'rs4871857': 'rs20575',
#  'rs28936068': 'rs151340631',
#  'rs28575995': 'rs4672916',
#  'rs11672943': 'rs11538454',
#  'rs63751295': 'rs587776529',
#  'rs41537746': 'rs4990383',
#  'rs28933997': 'rs121918592',
#  'rs55738533': 'rs4664277',
#  'rs28407157': 'rs4795541',
#  'rs569107562': 'rs398122988',
#  'rs8102646': 'rs45508602',
#  'rs28651161': 'rs7340047',
#  'rs10947776': 'rs9462475',
#  'rs56398245': 'rs2229020',
#  'rs775558514': 'rs75968137',
#  'rs1469122': 'rs1127390',
#  'rs35257590': 'rs2751790',
#  'rs28570051': 'rs3130689',
#  'rs72393999': 'rs34113117',
#  'rs11574048': 'rs2228572',
#  'rs3906345': 'rs446574',
#  'rs6540433': 'rs17617',
#  'rs63749928': 'rs587779129',
#  'rs12182983': 'rs9461218',
#  'rs9267522': 'rs11229',
#  'rs28935181': 'rs137854593',
#  'rs28936080': 'rs132630293',
#  'rs13406186': 'rs1397742',
#  'rs2073687': 'rs6735',
#  'rs386459970': 'rs45554035',
#  'rs34482187': 'rs3126868',
#  'rs28436602': 'rs28359170',
#  'rs28468602': 'rs3064655',
#  'rs12561187': 'rs9556545',
#  'rs63751404': 'rs587779057',
#  'rs10931450': 'rs4940',
#  'rs28934268': 'rs104894722',
#  'rs36036080': 'rs2755687',
#  'rs200040093': 'rs79432557',
#  'rs28935193': 'rs104894836',
#  'rs1982073': 'rs1800470',
#  'rs28723000': 'rs7849370',
#  'rs2805910': 'rs2229498',
#  'rs10782171': 'rs9481155',
#  'rs386543360': 'rs2230300',
#  'rs28932774': 'rs104894370',
#  'rs28939369': 'rs79833450',
#  'rs12401274': 'rs2751398',
#  'rs3094282': 'rs193303002',
#  'rs12016734': 'rs9595178',
#  'rs11572243': 'rs2228113',
#  'rs10741739': 'rs1140047',
#  'rs34293660': 'rs2759838',
#  'rs10085242': 'rs9498210',
#  'rs548749666': 'rs563223',
#  'rs28939091': 'rs111033258',
#  'rs11089853': 'rs9619704',
#  'rs16948568': 'rs11538868',
#  'rs10775033': 'rs9557573',
#  'rs28673438': 'rs2411401',
#  'rs28557337': 'rs17052208',
#  'rs386829199': 'rs201017328',
#  'rs566628613': 'rs1870867',
#  'rs35547721': 'rs2754995',
#  'rs9885921': 'rs9476511',
#  'rs148895749': 'rs1894377',
#  'rs63750251': 'rs587779083',
#  'rs28935173': 'rs121912288',
#  'rs35811659': 'rs80356820',
#  'rs8192282': 'rs2228144',
#  'rs4418557': 'rs2877815',
#  'rs560764272': 'rs7358275',
#  'rs28934882': 'rs119103215',
#  'rs386519578': 'rs45552433',
#  'rs10807614': 'rs9256',
#  'rs11540899': 'rs2230104',
#  'rs770634405': 'rs797045249',
#  'rs558935617': 'rs7928694',
#  'rs28939694': 'rs121908982',
#  'rs12714176': 'rs10901',
#  'rs9284357': 'rs6503006',
#  'rs12560891': 'rs9560323',
#  'rs35600288': 'rs3064744',
#  'rs28935205': 'rs137852382',
#  'rs28936082': 'rs104894838',
#  'rs7689418': 'rs9410',
#  'rs11147849': 'rs9525515',
#  'rs11592327': 'rs2952072',
#  'rs11908296': 'rs11553387',
#  'rs28617642': 'rs527236195',
#  'rs28936413': 'rs104893622',
#  'rs200050722': 'rs13338821',
#  'rs10807600': 'rs9464971',
#  'rs1138444': 'rs13848',
#  'rs28395509': 'rs9699595',
#  'rs28933096': 'rs121913574',
#  'rs28468984': 'rs7349165',
#  'rs12490432': 'rs2815996',
#  'rs11155360': 'rs9497012',
#  'rs61748405': 'rs122460157',
#  'rs3177999': 'rs1131596',
#  'rs28936969': 'rs137852414',
#  'rs12017896': 'rs9578371',
#  'rs28359186': 'rs5016142',
#  'rs12871898': 'rs11556093',
#  'rs12183235': 'rs9474062',
#  'rs6569605': 'rs2229848',
#  'rs7422651': 'rs8545',
#  'rs11149393': 'rs9551206',
#  'rs6788125': 'rs8274',
#  'rs34212701': 'rs2524541',
#  'rs4675141': 'rs1800517',
#  'rs7450800': 'rs2524166',
#  'rs17648360': 'rs14922',
#  'rs1799774': 'rs397832689',
#  'rs4606515': 'rs1126924',
#  'rs11247847': 'rs2736831',
#  'rs140711530': 'rs2229485',
#  'rs13100218': 'rs11540913',
#  'rs3783711': 'rs2229677',
#  'rs10882230': 'rs812017',
#  'rs756361508': 'rs730881619',
#  'rs3176975': 'rs4581',
#  'rs28939382': 'rs121918303',
#  'rs16875997': 'rs2227915',
#  'rs6747096': 'rs12457',
#  'rs1799919': 'rs1130674',
#  'rs12018672': 'rs9594084',
#  'rs41520546': 'rs41321145',
#  'rs28937297': 'rs137852451',
#  'rs3730814': 'rs2718886',
#  'rs28932778': 'rs121913673',
#  'rs4518636': 'rs1130474',
#  'rs10510146': 'rs9422897',
#  'rs28937299': 'rs137852455',
#  'rs12020504': 'rs9511660',
#  'rs34253002': 'rs10020631',
#  'rs202067650': 'rs79417681',
#  'rs11155879': 'rs9479419',
#  'rs2207730': 'rs1132156',
#  'rs149121504': 'rs4377812',
#  'rs746988059': 'rs137854528',
#  'rs12124283': 'rs1313343',
#  'rs386459940': 'rs13293961',
#  'rs12020178': 'rs9516276',
#  'rs58142816': 'rs2229182',
#  'rs4276100': 'rs1105439',
#  'rs10947595': 'rs9470242',
#  'rs143426821': 'rs61743362',
#  'rs28939692': 'rs121909491',
#  'rs28937269': 'rs137852406',
#  'rs12361947': 'rs11544721',
#  'rs35320409': 'rs4520441',
#  'rs7162473': 'rs2229749',
#  'rs757928483': 'rs869320677',
#  'rs10944448': 'rs9451228',
#  'rs12020228': 'rs9522049',
#  'rs12016871': 'rs9581854',
#  'rs1761608': 'rs1146245',
#  'rs9270305': 'rs707953',
#  'rs6562086': 'rs78630578',
#  'rs28939376': 'rs121908417',
#  'rs386519472': 'rs45628437',
#  'rs12267836': 'rs11558719',
#  'rs2320432': 'rs365712',
#  'rs3790419': 'rs1805134',
#  'rs28601282': 'rs527236199',
#  'rs12918952': 'rs11545029',
#  'rs12985668': 'rs2229139',
#  'rs6442089': 'rs1137524',
#  'rs5030671': 'rs2230529',
#  'rs28932776': 'rs121913670',
#  'rs2272199': 'rs2229813',
#  'rs8025316': 'rs3087532',
#  'rs28540897': 'rs10006687',
#  'rs7746261': 'rs10004',
#  'rs34636876': 'rs2754890',
#  'rs12180348': 'rs9480186',
#  'rs11147984': 'rs9562611',
#  'rs16950706': 'rs11537857',
#  'rs758671550': 'rs878853266',
#  'rs10484796': 'rs9483989',
#  'rs28357375': 'rs527236194',
#  'rs28936083': 'rs137852385',
#  'rs10471371': 'rs1801106',
#  'rs386541068': 'rs2228482',
#  'rs28933994': 'rs104893773',
#  'rs4908393': 'rs481640',
#  'rs35144989': 'rs12013756',
#  'rs138029418': 'rs78216937',
#  'rs9294977': 'rs6936256',
#  'rs28358268': 'rs9645429',
#  'rs12181871': 'rs9465019',
#  'rs10872388': 'rs9493173',
#  'rs10807146': 'rs9469931',
#  'rs17255497': 'rs1130972',
#  'rs28357377': 'rs527236198',
#  'rs8003865': 'rs761978',
#  'rs7871882': 'rs784682',
#  'rs16927965': 'rs1128362',
#  'rs28935215': 'rs137852402',
#  'rs1707162': 'rs1249804',
#  'rs63750025': 'rs587779249',
#  'rs540217899': 'rs908819',
#  'rs28929486': 'rs121917872',
#  'rs370896675': 'rs61738716',
#  'rs12179109': 'rs9463082',
#  'rs35505285': 'rs2771594',
#  'rs17055101': 'rs1058868',
#  'rs34815109': 'rs3064744',
#  'rs5851098': 'rs5851097',
#  'rs3820445': 'rs1128934',
#  'rs13304806': 'rs810801',
#  'rs4147719': 'rs1801318',
#  'rs10851266': 'rs9522306',
#  'rs111825882': 'rs61742436',
#  'rs10781952': 'rs9511900',
#  'rs28439204': 'rs11510098',
#  'rs10407115': 'rs1138439',
#  'rs537664866': 'rs4898439',
#  'rs9768008': 'rs1643164',
#  'rs4926219': 'rs2230539',
#  'rs28933083': 'rs121913136',
#  'rs2274756': 'rs17577',
#  'rs7488971': 'rs8815',
#  'rs35042476': 'rs2603158',
#  'rs10775105': 'rs9523360',
#  'rs12018260': 'rs9586383',
#  'rs9641370': 'rs1129293',
#  'rs28935172': 'rs56030372',
#  'rs12895000': 'rs11556216',
#  'rs28934269': 'rs104894502',
#  'rs28358275': 'rs193302927',
#  'rs28934893': 'rs118204059',
#  'rs10806782': 'rs9458876',
#  'rs4148628': 'rs1800851',
#  'rs9258122': 'rs3131866',
#  'rs11779592': 'rs12718',
#  'rs28933072': 'rs121918409',
#  'rs2854121': 'rs193302933',
#  'rs28933976': 'rs104894035',
#  'rs11575945': 'rs1131239',
#  'rs11242834': 'rs9501963',
#  'rs200946350': 'rs76792641',
#  'rs2073619': 'rs6624',
#  'rs2736654': 'rs4746',
#  'rs16930845': 'rs11544968',
#  'rs11153715': 'rs9489300',
#  'rs17034455': 'rs1143691',
#  'rs12184061': 'rs9505545',
#  'rs12178438': 'rs9491511',
#  'rs199620723': 'rs193302971',
#  'rs10493050': 'rs2377924',
#  'rs12017270': 'rs9578516',
#  'rs603965': 'rs9344',
#  'rs774683328': 'rs180177327',
#  'rs8033037': 'rs25458',
#  'rs193303005': 'rs3928305',
#  'rs12018489': 'rs9586871',
#  'rs6195': 'rs56149945',
#  'rs28937284': 'rs137852425',
#  'rs12484449': 'rs11546403',
#  'rs386420806': 'rs4978872',
#  'rs551114761': 'rs75164486',
#  'rs12019512': 'rs9508834',
#  'rs28936402': 'rs121909289',
#  'rs3732995': 'rs3196715',
#  'rs575532957': 'rs205743',
#  'rs2302652': 'rs2230299',
#  'rs7279064': 'rs1051393',
#  'rs28935208': 'rs137852386',
#  'rs28939093': 'rs119475041',
#  'rs28934894': 'rs121964998',
#  'rs10456958': 'rs9482650',
#  'rs28759196': 'rs9422290',
#  'rs281032': 'rs279590',
#  'rs315041': 'rs56012468',
#  'rs63751091': 'rs587779188',
#  'rs28380313': 'rs7340122',
#  'rs11147673': 'rs9509195',
#  'rs11148687': 'rs9507047',
#  'rs61726453': 'rs137852630',
#  'rs28358269': 'rs6650106',
#  'rs10458159': 'rs9503665',
#  'rs12178958': 'rs9490973',
#  'rs3732566': 'rs1042787',
#  'rs28937308': 'rs137852470',
#  'rs12169280': 'rs9627191',
#  'rs3847636': 'rs480269',
#  'rs28405897': 'rs9326618',
#  'rs36020501': 'rs2792347',
#  'rs75789617': 'rs2556973',
#  'rs17847305': 'rs2229192',
#  'rs16932374': 'rs2228317',
#  'rs7352186': 'rs2057077',
#  'rs34262498': 'rs2557148',
#  'rs777854': 'rs692811',
#  'rs10046212': 'rs9460171',
#  'rs3177554': 'rs1129411',
#  'rs12019525': 'rs9511436',
#  'rs2251741': 'rs1131830',
#  'rs11069395': 'rs9518075',
#  'rs12020901': 'rs9527865',
#  'rs34764213': 'rs2751984',
#  'rs28477125': 'rs2096045',
#  'rs28625947': 'rs2853819',
#  'rs587776556': 'rs397515517',
#  'rs572127300': 'rs11819434',
#  'rs34290728': 'rs2524607',
#  'rs10888390': 'rs2230061',
#  'rs10949413': 'rs9477363',
#  'rs12019764': 'rs9526911',
#  'rs747270765': 'rs202247803',
#  'rs10948888': 'rs9475176',
#  'rs10948240': 'rs9472506',
#  'rs28658869': 'rs12161765',
#  'rs71367103': 'rs34253442',
#  'rs386829245': 'rs200521299',
#  'rs3731151': 'rs2227998',
#  'rs3764092': 'rs14236',
#  'rs11544667': 'rs14968',
#  'rs4261065': 'rs4008432',
#  'rs11069824': 'rs9588090',
#  'rs28933975': 'rs121918015',
#  'rs200017298': 'rs75335225',
#  'rs28935192': 'rs104894835',
#  'rs28939374': 'rs121908415',
#  'rs11154032': 'rs9490291',
#  'rs12561491': 'rs9559272',
#  'rs35144699': 'rs7008729',
#  'rs28930978': 'rs121909548',
#  'rs3177778': 'rs1130592',
#  'rs17153910': 'rs480600',
#  'rs745989418': 'rs80338803',
#  'rs2048220': 'rs1129496',
#  'rs35978000': 'rs2563462',
#  'rs34798692': 'rs17496011',
#  'rs28939689': 'rs75654767',
#  'rs11549147': 'rs4731',
#  'rs28937277': 'rs137852416',
#  'rs9751212': 'rs6754555',
#  'rs28937276': 'rs137852415',
#  'rs12181911': 'rs9448923',
#  'rs17634737': 'rs11538197',
#  'rs12019494': 'rs9517683',
#  'rs3178178': 'rs10511',
#  'rs9699404': 'rs3126674',
#  'rs200108597': 'rs193303003',
#  'rs28933086': 'rs121913156',
#  'rs11069760': 'rs9559471',
#  'rs28936373': 'rs80356790',
#  'rs28687600': 'rs4968351',
#  'rs28499516': 'rs2298007',
#  'rs34829208': 'rs2559243',
#  'rs17286006': 'rs11550721',
#  'rs28493724': 'rs1832730',
#  'rs7536086': 'rs2230307',
#  'rs34949051': 'rs2535142',
#  'rs758561876': 'rs730881300',
#  'rs72494958': 'rs3773828',
#  'rs63750290': 'rs34204059',
#  'rs12183006': 'rs9472580',
#  'rs28737332': 'rs7036025',
#  'rs16874954': 'rs76863441',
#  'rs34994472': 'rs2750593',
#  'rs3742633': 'rs2230499',
#  'rs10872662': 'rs9498411',
#  'rs35855595': 'rs9659239',
#  'rs35858670': 'rs2756727',
#  'rs12018596': 'rs9590595',
#  'rs28932777': 'rs121913671',
#  'rs6413414': 'rs1130941',
#  'rs35762759': 'rs2266174',
#  'rs9966033': 'rs15350',
#  'rs4449438': 'rs2319258',
#  'rs9786231': 'rs2890624',
#  'rs2074797': 'rs1127821',
#  'rs12020190': 'rs9508660',
#  'rs9415986': 'rs1227043',
#  'rs11647465': 'rs11558678',
#  'rs12017501': 'rs9578495',
#  'rs28937293': 'rs137852445',
#  'rs10220127': 'rs9585764',
#  'rs34103881': 'rs3902259',
#  'rs12181971': 'rs9463241',
#  'rs28452651': 'rs2853499',
#  'rs527571160': 'rs398124464',
#  'rs4576294': 'rs1042116',
#  'rs7815040': 'rs2468893',
#  'rs28412854': 'rs10458597',
#  'rs13270305': 'rs11545077',
#  'rs11546721': 'rs137854665',
#  'rs61726454': 'rs137852631',
#  'rs10183712': 'rs2909444',
#  'rs4493274': 'rs4000988',
#  'rs41322148': 'rs7482144',
#  'rs114786114': 'rs2882903',
#  'rs12020194': 'rs9513408',
#  'rs1678160': 'rs12724',
#  'rs28936968': 'rs137852413',
#  'rs3026900': 'rs2228321',
#  'rs3177427': 'rs7975',
#  'rs28934275': 'rs121964969',
#  'rs11069386': 'rs9517922',
#  'rs28930974': 'rs104894101',
#  'rs28934887': 'rs111033542',
#  'rs3738099': 'rs3200254',
#  'rs7177092': 'rs2230940',
#  'rs13303653': 'rs11739759',
#  'rs34857375': 'rs1799762',
#  'rs12182899': 'rs9498072',
#  'rs28516704': 'rs9789635',
#  'rs35352606': 'rs2228363',
#  'rs769527482': 'rs12807209',
#  'rs3178055': 'rs9839',
#  'rs7553394': 'rs2230573',
#  'rs10498796': 'rs3195579',
#  'rs10498758': 'rs9472464',
#  'rs73994288': 'rs72558189',
#  'rs2242267': 'rs2229313',
#  'rs3177404': 'rs7961',
#  'rs12019900': 'rs9518018',
#  'rs12020540': 'rs9507809',
#  'rs17019360': 'rs2228460',
#  'rs12016950': 'rs9588597',
#  'rs12177758': 'rs9476499',
#  'rs12178386': 'rs9453295',
#  'rs4742754': 'rs2075663',
#  'rs372941874': 'rs143439055',
#  'rs4586425': 'rs1143685',
#  'rs28638124': 'rs8179414',
#  'rs386519577': 'rs45626240',
#  'rs12356072': 'rs9415997',
#  'rs28658038': 'rs55723650',
#  'rs150272782': 'rs76634974',
#  'rs28939383': 'rs137852944',
#  'rs35021742': 'rs2524575',
#  'rs3906005': 'rs708803',
#  'rs28935207': 'rs137852384',
#  'rs10872675': 'rs9478225',
#  'rs11852361': 'rs2227935',
#  'rs4667319': 'rs1143676',
#  'rs12769084': 'rs11538750',
#  'rs34731508': 'rs2767986',
#  'rs28358868': 'rs7340086',
#  'rs12182701': 'rs9491839',
#  'rs28933095': 'rs121912511',
#  'rs10679432': 'rs10633383',
#  'rs28358880': 'rs9699599',
#  'rs11135721': 'rs13530',
#  'rs35588459': 'rs690763',
#  'rs28933989': 'rs137853290',
#  'rs28940303': 'rs104894540',
#  'rs4475990': 'rs3983569',
#  'rs61735874': 'rs142934616',
#  'rs10129139': 'rs9588411',
#  'rs12019662': 'rs9510593',
#  'rs10807836': 'rs4468705',
#  'rs3737959': 'rs2230622',
#  'rs63750506': 'rs587779157',
#  'rs28933988': 'rs104894487',
#  'rs28933987': 'rs199469476',
#  'rs8176212': 'rs273900734',
#  'rs28357973': 'rs9629042',
#  'rs6542522': 'rs1132267',
#  'rs28939698': 'rs104894212',
#  'rs3741981': 'rs1131454',
#  'rs12179692': 'rs9466846',
#  'rs28935198': 'rs104894840',
#  'rs10851199': 'rs9520371',
#  'rs9424933': 'rs2653711',
#  'rs11149485': 'rs9512819',
#  'rs12459084': 'rs1130222',
#  'rs3903261': 'rs3020527',
#  'rs10949392': 'rs9464979',
#  'rs1801105': 'rs11558538',
#  'rs12018226': 'rs9590708',
#  'rs4730283': 'rs20556',
#  'rs28939381': 'rs121908130',
#  'rs56909176': 'rs5843453',
#  'rs6463524': 'rs1805319',
#  'rs12017058': 'rs9588107',
#  'rs28361044': 'rs12526327',
#  'rs34152967': 'rs5030739',
#  'rs9273327': 'rs2395228',
#  'rs552921547': 'rs568922',
#  'rs10508029': 'rs9584473',
#  'rs4608374': 'rs1123500',
#  'rs28934272': 'rs121918166',
#  'rs3937039': 'rs56489998',
#  'rs4556706': 'rs2383519',
#  'rs28932773': 'rs121434590',
#  'rs755576050': 'rs863224034',
#  'rs12018676': 'rs9583835',
#  'rs4721383': 'rs4719429',
#  'rs28937281': 'rs137852420',
#  'rs193303034': 'rs41456348',
#  'rs10871218': 'rs9553561',
#  'rs29001646': 'rs1142345',
#  'rs62514904': 'rs62508727',
#  'rs34667571': 'rs2573797',
#  'rs28935180': 'rs104894896',
#  'rs9782774': 'rs3014507',
#  'rs10943606': 'rs9443630',
#  'rs200469473': 'rs2574224',
#  'rs564232037': 'rs1417953',
#  'rs773821541': 'rs587777582',
#  'rs12019515': 'rs9524457',
#  'rs28935206': 'rs137852383',
#  'rs3817490': 'rs2228556',
#  'rs772666026': 'rs672601344',
#  'rs28358577': 'rs2897260',
#  'rs28933991': 'rs121918587',
#  'rs10872397': 'rs9493417',
#  'rs28935176': 'rs104894770',
#  'rs11929241': 'rs1128293',
#  'rs11976480': 'rs2228410',
#  'rs10164639': 'rs1134941',
#  'rs4149313': 'rs2066714',
#  'rs9868985': 'rs1127826',
#  'rs11658803': 'rs2230552',
#  'rs4033727': 'rs2534158',
#  'rs35042464': 'rs3014327',
#  'rs3764584': 'rs1133692',
#  'rs28605279': 'rs9633436',
#  'rs4239343': 'rs4021815',
#  'rs756314366': 'rs398123767',
#  'rs10871221': 'rs9507500',
#  'rs11069385': 'rs9557340',
#  'rs12886220': 'rs1138345',
#  'rs773369163': 'rs587776949',
#  'rs61748435': 'rs104894672',
#  'rs28532243': 'rs28371702',
#  'rs12689910': 'rs1131197',
#  'rs12178586': 'rs9448278',
#  'rs10775098': 'rs9522906',
#  'rs10507544': 'rs9562683',
#  'rs28772340': 'rs13206011',
#  'rs63750983': 'rs34623271',
#  'rs10485061': 'rs9479818',
#  'rs12180168': 'rs9473207',
#  'rs752395680': 'rs79680044',
#  'rs2854122': 'rs267606893',
#  'rs28362464': 'rs3745635',
#  'rs3783167': 'rs13508',
#  'rs11155751': 'rs9478812',
#  'rs28357983': 'rs9782892',
#  'rs11861251': 'rs1143680',
#  'rs11154598': 'rs9492675',
#  'rs12560420': 'rs9555790',
#  'rs8176750': 'rs56392308',
#  'rs12018446': 'rs9585062',
#  'rs4365706': 'rs4026962',
#  'rs5030815': 'rs5030814',
#  'rs6441516': 'rs11353',
#  'rs10775027': 'rs9513670',
#  'rs12179975': 'rs9501028',
#  'rs1802905': 'rs199475615',
#  'rs7111236': 'rs2230004',
#  'rs3816540': 'rs2229712',
#  'rs3810710': 'rs2229137',
#  'rs7349077': 'rs1800891',
#  'rs28935214': 'rs137852401',
#  'rs12018528': 'rs9591796',
#  'rs28371731': 'rs4987144',
#  'rs28937295': 'rs111033615',
#  'rs28939708': 'rs121908674',
#  'rs28358575': 'rs28358574',
#  'rs10946327': 'rs9460376',
#  'rs28937270': 'rs137852407',
#  'rs61726449': 'rs137852629',
#  'rs34969950': 'rs2759868',
#  'rs4030030': 'rs2755293',
#  'rs7031748': 'rs2853579',
#  'rs10781779': 'rs9525807',
#  'rs12020531': 'rs9506350',
#  'rs8039': 'rs57122389',
#  'rs2292566': 'rs1131873',
#  'rs8049651': 'rs2229193',
#  'rs63751631': 'rs267607868',
#  'rs760773815': 'rs397514425',
#  'rs9671004': 'rs9515129',
#  'rs12561458': 'rs9553706',
#  'rs775056460': 'rs121908744',
#  'rs13304827': 'rs2525376',
#  'rs457155': 'rs230259',
#  'rs767508544': 'rs199422176',
#  'rs12020349': 'rs9510047',
#  'rs7774011': 'rs1053192',
#  'rs7177445': 'rs13598',
#  'rs11231210': 'rs542242',
#  'rs28936970': 'rs137852464',
#  'rs756270039': 'rs111033407',
#  'rs28936392': 'rs121912578',
#  'rs10979601': 'rs2230792',
#  'rs17415659': 'rs1126797',
#  'rs34957480': 'rs2538838',
#  'rs386525800': 'rs45530037',
#  'rs17273330': 'rs4020729',
#  'rs12178302': 'rs9486686',
#  'rs3738372': 'rs17599',
#  'rs755661160': 'rs61745490',
#  'rs28587363': 'rs9701872',
#  'rs28937305': 'rs137852468',
#  'rs28934001': 'rs193922826',
#  'rs775837019': 'rs111033306',
#  'rs36001425': 'rs2557319',
#  'rs17337023': 'rs2227984',
#  'rs746786134': 'rs150594063',
#  'rs1610628': 'rs113795410',
#  'rs28405534': 'rs2892809',
#  'rs63751402': 'rs281864898',
#  'rs10429965': 'rs2230489',
#  'rs386561769': 'rs2230189',
#  'rs756844187': 'rs387906256',
#  'rs10943837': 'rs9449384',
#  'rs778530487': 'rs431825381',
#  'rs17846179': 'rs1805127',
#  'rs11244705': 'rs11461',
#  'rs28939699': 'rs121434430',
#  'rs63750038': 'rs587778884',
#  'rs28357092': 'rs532781899',
#  'rs41337244': 'rs527236193',
#  'rs28357682': 'rs527236203',
#  'rs6547876': 'rs1128416',
#  'rs11799112': 'rs6652934',
#  'rs10828317': 'rs2230469',
#  'rs535061516': 'rs6681821',
#  'rs3177478': 'rs1129157',
#  'rs28671069': 'rs5018194',
#  'rs28940304': 'rs104894541',
#  'rs10755488': 'rs9451108',
#  'rs11944159': 'rs11555334',
#  'rs28937275': 'rs137852412',
#  'rs553538425': 'rs7934077',
#  'rs11147341': 'rs9508098',
#  'rs144858546': 'rs3014785',
#  'rs12177532': 'rs9450620',
#  'rs28649878': 'rs7053608',
#  'rs3800859': 'rs1130501',
#  'rs10888734': 'rs8375',
#  'rs4986998': 'rs1131341',
#  'rs12018363': 'rs9581329',
#  'rs3747531': 'rs2229388',
#  'rs12180015': 'rs9481844',
#  'rs4402510': 'rs4068854',
#  'rs28932772': 'rs137853216',
#  'rs11147467': 'rs9594198',
#  'rs11069247': 'rs9554369',
#  'rs7737000': 'rs2228141',
#  'rs10945865': 'rs9458668',
#  'rs17258982': 'rs17618',
#  'rs7227107': 'rs25656',
#  'rs5743266': 'rs2076752',
#  'rs150826625': 'rs76125935',
#  'rs762828343': 'rs121908747',
#  'rs532606556': 'rs3781564',
#  'rs1136701': 'rs4575',
#  'rs8192284': 'rs2228145',
#  'rs28583298': 'rs4072393',
#  'rs368279144': 'rs75202392',
#  'rs10943426': 'rs9447985',
#  'rs3177979': 'rs1131476',
#  'rs386518927': 'rs11545763',
#  'rs4378525': 'rs2025396',
#  'rs7225748': 'rs1081100',
#  'rs28357372': 'rs527236210',
#  'rs28939700': 'rs121908958',
#  'rs12019474': 'rs9514039',
#  'rs11572279': 'rs2229191',
#  'rs28939377': 'rs119478058',
#  'rs552542260': 'rs527236050',
#  'rs3177964': 'rs1131398',
#  'rs17154667': 'rs2230156',
#  'rs28358881': 'rs9783079',
#  'rs12017236': 'rs9578046',
#  'rs63750148': 'rs587776530',
#  'rs2251862': 'rs1133228',
#  'rs34683662': 'rs2522625',
#  'rs12009120': 'rs2230488',
#  'rs12721531': 'rs2230877',
#  'rs28936971': 'rs137854612',
#  'rs28720026': 'rs1671926',
#  'rs35578984': 'rs2790921',
#  'rs12018299': 'rs9585932',
#  'rs386525798': 'rs45444695',
#  'rs28623747': 'rs9645428',
#  'rs12020389': 'rs9511865',
#  'rs12181895': 'rs9486419',
#  'rs386541775': 'rs2229753',
#  'rs1359185': 'rs1128105',
#  'rs28750717': 'rs249324',
#  'rs34488815': 'rs2000975',
#  'rs10080421': 'rs9499856',
#  'rs11882865': 'rs1133893',
#  'rs28619014': 'rs11510103',
#  'rs5030652': 'rs199475631',
#  'rs35976751': 'rs17162742',
#  'rs780367421': 'rs587777921',
#  'rs9703900': 'rs9416557',
#  'rs362204': 'rs397758621',
#  'rs575423658': 'rs4301800',
#  'rs10737812': 'rs1131449',
#  'rs17286075': 'rs162346',
#  'rs12180434': 'rs9498943',
#  'rs4518475': 'rs594671',
#  'rs386616115': 'rs45573936',
#  'rs10947803': 'rs9471058',
#  'rs11147542': 'rs9592258',
#  'rs63750076': 'rs587778931',
#  'rs28414989': 'rs3899049',
#  'rs17098707': 'rs2230345',
#  'rs28937298': 'rs137852453',
#  'rs8192894': 'rs9778',
#  'rs3738383': 'rs17596',
#  'rs11227756': 'rs2228418',
#  'rs4461510': 'rs2389688',
#  'rs11593766': 'rs11555408',
#  'rs34968564': 'rs33947112',
#  'rs35933219': 'rs3833842',
#  'rs28937290': 'rs137852442',
#  'rs34910997': 'rs34363638',
#  'rs28647521': 'rs9722048',
#  'rs10851295': 'rs9522932',
#  'rs2228005': 'rs1805319',
#  'rs775581758': 'rs587606221',
#  'rs12018747': 'rs9595806',
#  'rs28688240': 'rs750403',
#  'rs3177980': 'rs1131498',
#  'rs28628414': 'rs11510099',
#  'rs6458687': 'rs8589',
#  'rs10871227': 'rs9512056',
#  'rs3829990': 'rs8094',
#  'rs751695119': 'rs878854998',
#  'rs9303634': 'rs6561',
#  'rs10870625': 'rs9508490',
#  'rs28464283': 'rs9651229',
#  'rs36042884': 'rs2566039',
#  'rs17104257': 'rs11540216',
#  'rs8179183': 'rs1805094',
#  'rs2281891': 'rs1126545',
#  'rs12020039': 'rs9522257',
#  'rs28407114': 'rs9629043',
#  'rs2305295': 'rs8154',
#  'rs777276993': 'rs863224041',
#  'rs768209865': 'rs80356479',
#  'rs11148792': 'rs9564502',
#  'rs770958043': 'rs587593757',
#  'rs28507745': 'rs7552878',
#  'rs17850886': 'rs11539893',
#  'rs28937273': 'rs111033616',
#  'rs28935183': 'rs121434618',
#  'rs2725362': 'rs1801195',
#  'rs28934270': 'rs104894503',
#  'rs4636966': 'rs4057208',
#  'rs7418088': 'rs5020501',
#  'rs7858186': 'rs784681',
#  'rs2266988': 'rs1129172',
#  'rs4986956': 'rs2229207',
#  'rs28937304': 'rs137852467',
#  'rs12179084': 'rs9494192',
#  'rs11572193': 'rs2229189',
#  'rs66913555': 'rs66913554',
#  'rs34263369': 'rs2535823',
#  'rs4440505': 'rs2400131',
#  'rs12410855': 'rs11556464',
#  'rs11088262': 'rs4842',
#  'rs10851111': 'rs9585299',
#  'rs11070052': 'rs9524002',
#  'rs28933969': 'rs121913506',
#  'rs3177751': 'rs1130426',
#  'rs12019782': 'rs9511505',
#  'rs12183238': 'rs9498958',
#  'rs10806731': 'rs9457918',
#  'rs386513263': 'rs10482707',
#  'rs779016080': 'rs112669694',
#  'rs36044208': 'rs2525213',
#  'rs28933080': 'rs35020253',
#  'rs3764781': 'rs2228339',
#  'rs10084915': 'rs1134065',
#  'rs11148968': 'rs9565106',
#  'rs12427062': 'rs11558556',
#  'rs10851248': 'rs9521865',
#  'rs12721532': 'rs2230878',
#  'rs1058207': 'rs4824',
#  'rs5030806': 'rs104893829',
#  'rs35626468': 'rs381398',
#  'rs2692520': 'rs1127362',
#  'rs10872715': 'rs9478620',
#  'rs12020729': 'rs9510075',
#  'rs2241649': 'rs1128433',
#  'rs28937306': 'rs137852355',
#  'rs2288123': 'rs1131071',
#  'rs10467352': 'rs9551777',
#  'rs28937280': 'rs137852419',
#  'rs3815246': 'rs1735499',
#  'rs28935213': 'rs137852393',
#  'rs4243221': 'rs1143689',
#  'rs10851110': 'rs9517919',
#  'rs76501352': 'rs1798296',
#  'rs17085433': 'rs3848003',
#  'rs762198323': 'rs387906225',
#  'rs3088309': 'rs527236209',
#  'rs28546855': 'rs1972379',
#  'rs34938108': 'rs2556654',
#  'rs531244951': 'rs587783021',
#  'rs28389792': 'rs1832731',
#  'rs28357069': 'rs2734319',
#  'rs5328': 'rs5327',
#  'rs12177661': 'rs9458933',
#  'rs386462936': 'rs200068984',
#  'rs28934273': 'rs137853594',
#  'rs35599306': 'rs2476057',
#  'rs12017585': 'rs9595194',
#  'rs4527956': 'rs1599847',
#  'rs6063377': 'rs1130146',
#  'rs12181780': 'rs9487082',
#  'rs10747145': 'rs9591809',
#  'rs11150843': 'rs1042395',
#  'rs17850798': 'rs15570',
#  'rs4254648': 'rs1125218',
#  'rs28379759': 'rs9701296',
#  'rs12020018': 'rs9517133',
#  'rs532223973': 'rs1617603',
#  'rs2802211': 'rs1130683',
#  'rs534275065': 'rs387906560',
#  'rs568346063': 'rs6978148',
#  'rs3832852': 'rs1799759',
#  'rs11070121': 'rs9516568',
#  'rs28358869': 'rs2185536',
#  'rs3731824': 'rs1138484',
#  'rs147842490': 'rs28364786',
#  'rs28936076': 'rs104894741',
#  'rs12181097': 'rs9445700',
#  'rs1530100': 'rs1126839',
#  'rs6519457': 'rs28940585',
#  'rs28637797': 'rs10437110',
#  'rs7109335': 'rs10615',
#  'rs16967004': 'rs2230672',
#  'rs386519465': 'rs45610843',
#  'rs66785830': 'rs66785829',
#  'rs2189335': 'rs12761',
#  'rs748520270': 'rs587603119',
#  'rs28472843': 'rs5893596',
#  'rs12181514': 'rs9462076',
#  'rs1801200': 'rs1136201',
#  'rs33959111': 'rs1805121',
#  'rs12183132': 'rs9481254',
#  'rs28933986': 'rs121918143',
#  'rs28936369': 'rs121917850',
#  'rs11076173': 'rs5802',
#  'rs3178794': 'rs1134956',
#  'rs28937274': 'rs137852411',
#  'rs36030761': 'rs2750592',
#  'rs4276244': 'rs2333533',
#  'rs527806787': 'rs4873815',
#  'rs12561468': 'rs9555110',
#  'rs12021080': 'rs9521610',
#  'rs10851096': 'rs9517456',
#  'rs11070097': 'rs9524609',
#  'rs7394286': 'rs4934285',
#  'rs28933101': 'rs121913668',
#  'rs12020313': 'rs9524090',
#  'rs28937296': 'rs137852450',
#  'rs369366978': 'rs2130655',
#  'rs28437189': 'rs136920',
#  'rs3923616': 'rs1122922',
#  'rs10807151': 'rs9470063',
#  'rs4029042': 'rs2750628',
#  'rs9488519': 'rs384803',
#  'rs10214475': 'rs9504961',
#  'rs10499173': 'rs9492441',
#  'rs11187418': 'rs813709',
#  'rs12183109': 'rs9461073',
#  'rs11070111': 'rs9590198',
#  'rs12178530': 'rs9495141',
#  'rs1818952': 'rs1133384',
#  'rs28933084': 'rs121913139',
#  ...}

# %% [markdown]
# # Update rs, chr, pos in build36 files

# %% [markdown]
# ## Load dbSNP file

# %%
# %%time
# dbSNP file which contains rsNumber, chromosome and its position
SNPChrPosOnRef = None

# Look up SNP positions from rs number
with gzip.open('/home/tun01458/lib/dbSNP/b132_SNPChrPosOnRef_37_1.bcp.gz',
               'rb') as f_gz:
    f_SNPChrPosOnRef = io.BufferedReader(f_gz)  # speed up read
    SNPChrPosOnRef = pd.read_csv(f_SNPChrPosOnRef,
                                 sep='\t',
                                 usecols=[0, 1, 2],
                                 names=['rsid', 'chr', 'pos'])

print(SNPChrPosOnRef.shape)
SNPChrPosOnRef.head()
# Out:
# (30443446, 3)
# CPU times: user 17.9 s, sys: 2.46 s, total: 20.3 s
# Wall time: 20.4 s
#    rsid chr         pos
# 0     3  13  32446841.0
# 1     4  13  32447221.0
# 2     5   7  91839109.0
# 3     6   7  91747130.0
# 4     7   7  91779556.0

# %%
# SNPChrPosOnRef['chr'].value_counts()

# %%
# SNPChrPosOnRef = SNPChrPosOnRef[(SNPChrPosOnRef['chr'] != 'Multi')
#                                 & (SNPChrPosOnRef['chr'] != 'X')
#                                 & (SNPChrPosOnRef['chr'] != 'Y')
#                                 & (SNPChrPosOnRef['chr'] != 'NotOn')
#                                 & (SNPChrPosOnRef['chr'] != 'Un')
#                                 & (SNPChrPosOnRef['chr'] != 'PAR')
#                                 & (SNPChrPosOnRef['chr'] != 'AltOnly')
#                                 & (SNPChrPosOnRef['chr'] != 'MT')]

# %%
# # remove missing value in pos
# SNPChrPosOnRef = SNPChrPosOnRef[~SNPChrPosOnRef['pos'].isna()]

# %%
# add prefix to rsid
SNPChrPosOnRef['rsid'] = 'rs' + SNPChrPosOnRef['rsid'].astype(str)

# %%
# set rsid as index
SNPChrPosOnRef = SNPChrPosOnRef.set_index(['rsid'])

# %%
SNPChrPosOnRef.head()
# Out:
#      chr         pos
# rsid
# rs3   13  32446841.0
# rs4   13  32447221.0
# rs5    7  91839109.0
# rs6    7  91747130.0
# rs7    7  91779556.0

# %% [markdown]
# ## Update build36 file each file

# %%
# %%time
# load genotype
for i, filename in enumerate(build36_genotype_filenames):
    print('{}/{}'.format(i + 1, len(build36_genotype_filenames)))
    print(filename)

    build36_genotype = pd.read_csv(os.path.join('user_data/build36_genotype/',
                                                filename),
                                   sep='\t',
                                   header=None,
                                   names=['rsid', 'chr', 'pos', 'genotype'],
                                   comment='#')

    # update rs number
    build36_genotype.replace({'rsid': RsNum_MAP})
    build36_genotype = build36_genotype.set_index(['rsid'])

    # update chr and pos
    build36_genotype.update(SNPChrPosOnRef)

    # convert pos dtypes as int32
    build36_genotype = build36_genotype.astype({'pos': 'int32'})
    build36_genotype['pos'] = build36_genotype['pos'] + 1

    # write to file
    comment = '''# This data was lifted from build36 to build37. Below is original information. 
# ********* Original Information ***********
# This data file generated by 23andMe at: Wed Nov  2 19:32:28 2011
#
# Below is a text version of your data. Fields are TAB-separated
# Each line corresponds to a single SNP.  For each SNP, we provide its identifier
# (an rsid or an internal id), its location on the reference human genome, and the
# genotype call oriented with respect to the plus strand on the human reference
# sequence.     We are using reference human assembly build 36.  Note that it is possible
# that data downloaded at different times may be different due to ongoing improvements
# in our ability to call genotypes. More information about these changes can be found at:
# https://www.23andme.com/you/download/revisions/
#
# More information on reference human assembly build 36:
# http://www.ncbi.nlm.nih.gov/projects/mapview/map_search.cgi?taxid=9606&build=36
#
# rsid	chromosome	position	genotype'''
    with open(os.path.join('user_data/lifted_build36_to_build37/', filename),
              'w') as f:
        f.write(comment + '\n')
        build36_genotype.to_csv(f, sep='\t', header=None)
# Out:
# 1/66
# user123_file54_yearofbirth_unknown_sex_unknown.23andme.txt
# <string>:2: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
# 2/66
# user549_file252_yearofbirth_1948_sex_XY.23andme.txt
# 3/66
# user202_file85_yearofbirth_unknown_sex_unknown.23andme.txt
# 4/66
# user146_file62_yearofbirth_1971_sex_XY.23andme.txt
# 5/66
# user64_file30_yearofbirth_1965_sex_XY.23andme.txt
# 6/66
# user595_file277_yearofbirth_unknown_sex_unknown.23andme.txt
# 7/66
# user26_file10_yearofbirth_unknown_sex_unknown.23andme.txt
# 8/66
# user22_file8_yearofbirth_1975_sex_XY.23andme.txt
# 9/66
# user14_file6_yearofbirth_unknown_sex_unknown.23andme.txt
# 10/66
# user481_file215_yearofbirth_unknown_sex_unknown.23andme.txt
# 11/66
# user468_file200_yearofbirth_1978_sex_XX.23andme.txt
# 12/66
# user347_file157_yearofbirth_1952_sex_XX.23andme.txt
# 13/66
# user296_file127_yearofbirth_unknown_sex_unknown.23andme.txt
# 14/66
# user865_file427_yearofbirth_1979_sex_XY.23andme.txt
# 15/66
# user75_file39_yearofbirth_1982_sex_XY.23andme.txt
# 16/66
# user60_file27_yearofbirth_1982_sex_XY.23andme.txt
# 17/66
# user55_file24_yearofbirth_unknown_sex_unknown.23andme.txt
# 18/66
# user279_file113_yearofbirth_unknown_sex_unknown.23andme.txt
# 19/66
# user139_file59_yearofbirth_unknown_sex_unknown.23andme.txt
# 20/66
# user430_file328_yearofbirth_1986_sex_XX.23andme.txt
# 21/66
# user99_file49_yearofbirth_1986_sex_XY.23andme.txt
# 22/66
# user325_file149_yearofbirth_1987_sex_XY.23andme.txt
# 23/66
# user285_file118_yearofbirth_1976_sex_XY.23andme.txt
# 24/66
# user42_file18_yearofbirth_1985_sex_XY.23andme.txt
# 25/66
# user11_file176_yearofbirth_unknown_sex_unknown.23andme.txt
# 26/66
# user13_file4_yearofbirth_1979_sex_XY.23andme.txt
# 27/66
# user159_file67_yearofbirth_1984_sex_XX.23andme.txt
# 28/66
# user294_file125_yearofbirth_1963_sex_XY.23andme.txt
# 29/66
# user10_file3_yearofbirth_1982_sex_XY.23andme.txt
# 30/66
# user74_file48_yearofbirth_unknown_sex_XY.23andme.txt
# 31/66
# user341_file155_yearofbirth_unknown_sex_unknown.23andme.txt
# 32/66
# user262_file103_yearofbirth_1975_sex_XY.23andme.txt
# 33/66
# user33_file12_yearofbirth_unknown_sex_unknown.23andme.txt
# 34/66
# user36_file14_yearofbirth_1986_sex_XY.23andme.txt
# 35/66
# user368_file168_yearofbirth_1958_sex_XX.23andme.txt
# 36/66
# user397_file178_yearofbirth_1961_sex_XY.23andme.txt
# 37/66
# user207_file89_yearofbirth_unknown_sex_unknown.23andme.txt
# 38/66
# user276_file110_yearofbirth_1972_sex_XY.23andme.txt
# 39/66
# user441_file199_yearofbirth_1989_sex_XY.23andme.txt
# 40/66
# user1_file9_yearofbirth_1985_sex_XY.23andme.txt
# 41/66
# user495_file223_yearofbirth_1965_sex_XX.23andme.txt
# 42/66
# user411_file183_yearofbirth_unknown_sex_unknown.23andme.txt
# 43/66
# user86_file159_yearofbirth_1986_sex_XY.23andme.txt
# 44/66
# user539_file246_yearofbirth_1983_sex_XX.23andme.txt
# 45/66
# user463_file197_yearofbirth_1985_sex_XY.23andme.txt
# 46/66
# user125_file56_yearofbirth_1976_sex_XY.23andme.txt
# 47/66
# user80_file41_yearofbirth_1979_sex_XY.23andme.txt
# 48/66
# user81_file42_yearofbirth_1977_sex_XY.23andme.txt
# 49/66
# user8_file2_yearofbirth_unknown_sex_XX.23andme.txt
# 50/66
# user437_file190_yearofbirth_1973_sex_XY.23andme.txt
# 51/66
# user161_file68_yearofbirth_unknown_sex_unknown.23andme.txt
# 52/66
# user366_file167_yearofbirth_1950_sex_XY.23andme.txt
# 53/66
# user6882_file6340_yearofbirth_1982_sex_XX.23andme.txt
# 54/66
# user337_file152_yearofbirth_unknown_sex_unknown.23andme.txt
# 55/66
# user330_file146_yearofbirth_unknown_sex_XY.23andme.txt
# 56/66
# user160_file153_yearofbirth_1954_sex_unknown.23andme.txt
# 57/66
# user17_file143_yearofbirth_unknown_sex_XX.23andme.txt
# 58/66
# user363_file165_yearofbirth_unknown_sex_unknown.23andme.txt
# 59/66
# user35_file5822_yearofbirth_unknown_sex_XY.23andme.txt
# 60/66
# user380_file172_yearofbirth_unknown_sex_XY.23andme.txt
# 61/66
# user502_file226_yearofbirth_unknown_sex_unknown.23andme.txt
# 62/66
# user287_file120_yearofbirth_unknown_sex_unknown.23andme.txt
# 63/66
# user323_file142_yearofbirth_1983_sex_XY.23andme.txt
# 64/66
# user429_file187_yearofbirth_1950_sex_XY.23andme.txt
# 65/66
# user63_file31_yearofbirth_unknown_sex_unknown.23andme.txt
# 66/66
# user62_file29_yearofbirth_1966_sex_XY.23andme.txt
# CPU times: user 1h 10min 19s, sys: 5min 26s, total: 1h 15min 45s
# Wall time: 1h 16min 11s

# %%
build36_genotype.head()
# Out:
#            chr      pos genotype
# rsid
# rs3094315    1   752566       AA
# rs12562034   1   768448       AG
# rs3934834    1  1005806       CC
# rs9442372    1  1018704       AA
# rs3737728    1  1021415       AG
